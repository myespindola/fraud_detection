# %% [markdown]
# ## EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data_path = "../data/fraud_train.csv"
df = pd.read_csv(data_path)

# %%
pd.set_option('display.max_columns', None)
display(df.head())
# Out:
#            ID Month  WeekOfMonth DayOfWeek       Make AccidentArea  \
# 0  CL00007646   Aug            4    Friday      Honda        Urban
# 1  CL00009711   Dec            2   Tuesday  Chevrolet        Urban
# 2  CL00010809   Feb            2    Sunday  Chevrolet        Urban
# 3  CL00012496   Jun            3   Tuesday    Pontiac        Urban
# 4  CL00015396   Jan            2    Sunday     Toyota        Rural
#
#   DayOfWeekClaimed MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  \
# 0           Monday          Aug                   5    Male       Married
# 1        Wednesday          Dec                   3  Female        Single
# 2           Monday          Feb                   3    Male        Single
# 3         Thursday          Jul                   4    Male       Married
# 4         Thursday          Jan                   3    Male        Single
#
#            Fault          PolicyType VehicleCategory     VehiclePrice  \
# 0  Policy Holder  Sedan - All Perils           Sedan   30000 to 39000
# 1    Third Party   Sedan - Collision           Sedan   20000 to 29000
# 2  Policy Holder   Sedan - Liability           Sport   20000 to 29000
# 3  Policy Holder   Sedan - Collision           Sedan   20000 to 29000
# 4  Policy Holder  Sedan - All Perils           Sedan  less than 20000
#
#    FraudFound_P  Deductible Days_Policy_Accident Days_Policy_Claim  \
# 0             0         400         more than 30      more than 30
# 1             0         400         more than 30      more than 30
# 2             0         400         more than 30      more than 30
# 3             0         400         more than 30      more than 30
# 4             1         400         more than 30      more than 30
#
#   PastNumberOfClaims AgeOfVehicle AgeOfPolicyHolder PoliceReportFiled  \
# 0                  1      7 years          36 to 40                No
# 1             2 to 4      5 years          31 to 35                No
# 2             2 to 4      6 years          31 to 35                No
# 3                  1      7 years          41 to 50                No
# 4               none      6 years          36 to 40                No
#
#   WitnessPresent AgentType NumberOfSuppliments AddressChange_Claim  \
# 0             No  External              1 to 2        4 to 8 years
# 1             No  External                none           no change
# 2             No  External         more than 5           no change
# 3             No  External                none           no change
# 4             No  External                none           no change
#
#   NumberOfCars  Year  BasePolicy
# 0   2 vehicles  1994  All Perils
# 1    1 vehicle  1994   Collision
# 2    1 vehicle  1994   Liability
# 3    1 vehicle  1994   Collision
# 4    1 vehicle  1994  All Perils

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    5000 non-null   object
#  1   Month                 5000 non-null   object
#  2   WeekOfMonth           5000 non-null   int64
#  3   DayOfWeek             5000 non-null   object
#  4   Make                  5000 non-null   object
#  5   AccidentArea          5000 non-null   object
#  6   DayOfWeekClaimed      5000 non-null   object
#  7   MonthClaimed          5000 non-null   object
#  8   WeekOfMonthClaimed    5000 non-null   int64
#  9   Sex                   5000 non-null   object
#  10  MaritalStatus         5000 non-null   object
#  11  Fault                 5000 non-null   object
#  12  PolicyType            5000 non-null   object
#  13  VehicleCategory       5000 non-null   object
#  14  VehiclePrice          5000 non-null   object
#  15  FraudFound_P          5000 non-null   int64
#  16  Deductible            5000 non-null   int64
#  17  Days_Policy_Accident  5000 non-null   object
#  18  Days_Policy_Claim     5000 non-null   object
#  19  PastNumberOfClaims    5000 non-null   object
#  20  AgeOfVehicle          5000 non-null   object
#  21  AgeOfPolicyHolder     5000 non-null   object
#  22  PoliceReportFiled     5000 non-null   object
#  23  WitnessPresent        5000 non-null   object
#  24  AgentType             5000 non-null   object
#  25  NumberOfSuppliments   5000 non-null   object
#  26  AddressChange_Claim   5000 non-null   object
#  27  NumberOfCars          5000 non-null   object
#  28  Year                  5000 non-null   int64
#  29  BasePolicy            5000 non-null   object
# dtypes: int64(5), object(25)
# memory usage: 1.1+ MB

# %%
unique_counts = df.nunique()
display(unique_counts)
# Out:
# ID                      5000
# Month                     12
# WeekOfMonth                5
# DayOfWeek                  7
# Make                      18
# AccidentArea               2
# DayOfWeekClaimed           8
# MonthClaimed              13
# WeekOfMonthClaimed         5
# Sex                        2
# MaritalStatus              4
# Fault                      2
# PolicyType                 9
# VehicleCategory            3
# VehiclePrice               6
# FraudFound_P               2
# Deductible                 4
# Days_Policy_Accident       5
# Days_Policy_Claim          4
# PastNumberOfClaims         4
# AgeOfVehicle               8
# AgeOfPolicyHolder          9
# PoliceReportFiled          2
# WitnessPresent             2
# AgentType                  2
# NumberOfSuppliments        4
# AddressChange_Claim        5
# NumberOfCars               4
# Year                       3
# BasePolicy                 3
# dtype: int64

# %%
df.drop(columns=['ID'], inplace=True)

# %%
dup_rows = df.duplicated().sum()
print(f"Número de filas duplicadas completas: {dup_rows}")
# Out:
# Número de filas duplicadas completas: 0

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='FraudFound_P')
plt.title('Distribución de casos fraudulentos (1) y no fraudulentos (0)')
plt.show()

# %%
fraud_counts = df['FraudFound_P'].value_counts()
print(f"Porcentaje fraude: {fraud_counts[1] / fraud_counts.sum() * 100:.2f}%")
# Out:
# Porcentaje fraude: 5.84%

# %%
cat_columns =  [col for col in df.columns if col != 'FraudFound_P']

# %%
for col in cat_columns:
    print(col)
    print(df[col].unique())
# Out:
# Month
# ['Aug' 'Dec' 'Feb' 'Jun' 'Jan' 'Nov' 'Jul' 'May' 'Oct' 'Sep' 'Mar' 'Apr']
# WeekOfMonth
# [4 2 3 1 5]
# DayOfWeek
# ['Friday' 'Tuesday' 'Sunday' 'Monday' 'Thursday' 'Wednesday' 'Saturday']
# Make
# ['Honda' 'Chevrolet' 'Pontiac' 'Toyota' 'Mazda' 'Ford' 'Accura' 'Mercury'
#  'VW' 'Saturn' 'Dodge' 'Saab' 'BMW' 'Nisson' 'Porche' 'Ferrari' 'Jaguar'
#  'Mecedes']
# AccidentArea
# ['Urban' 'Rural']
# DayOfWeekClaimed
# ['Monday' 'Wednesday' 'Thursday' 'Tuesday' 'Friday' 'Saturday' 'Sunday'
#  '0']
# MonthClaimed
# ['Aug' 'Dec' 'Feb' 'Jul' 'Jan' 'Jun' 'Nov' 'Oct' 'Mar' 'May' 'Sep' 'Apr'
#  '0']
# WeekOfMonthClaimed
# [5 3 4 2 1]
# Sex
# ['Male' 'Female']
# MaritalStatus
# ['Married' 'Single' 'Divorced' 'Widow']
# Fault
# ['Policy Holder' 'Third Party']
# PolicyType
# ['Sedan - All Perils' 'Sedan - Collision' 'Sedan - Liability'
#  'Sport - Collision' 'Utility - All Perils' 'Utility - Collision'
#  'Utility - Liability' 'Sport - All Perils' 'Sport - Liability']
# VehicleCategory
# ['Sedan' 'Sport' 'Utility']
# VehiclePrice
# ['30000 to 39000' '20000 to 29000' 'less than 20000' 'more than 69000'
#  '40000 to 59000' '60000 to 69000']
# Deductible
# [400 500 700 300]
# Days_Policy_Accident
# ['more than 30' 'none' '1 to 7' '8 to 15' '15 to 30']
# Days_Policy_Claim
# ['more than 30' '15 to 30' '8 to 15' 'none']
# PastNumberOfClaims
# ['1' '2 to 4' 'none' 'more than 4']
# AgeOfVehicle
# ['7 years' '5 years' '6 years' '3 years' 'more than 7' 'new' '2 years'
#  '4 years']
# AgeOfPolicyHolder
# ['36 to 40' '31 to 35' '41 to 50' '18 to 20' '51 to 65' 'over 65'
#  '26 to 30' '16 to 17' '21 to 25']
# PoliceReportFiled
# ['No' 'Yes']
# WitnessPresent
# ['No' 'Yes']
# AgentType
# ['External' 'Internal']
# NumberOfSuppliments
# ['1 to 2' 'none' 'more than 5' '3 to 5']
# AddressChange_Claim
# ['4 to 8 years' 'no change' '2 to 3 years' '1 year' 'under 6 months']
# NumberOfCars
# ['2 vehicles' '1 vehicle' '3 to 4' '5 to 8']
# Year
# [1994 1996 1995]
# BasePolicy
# ['All Perils' 'Collision' 'Liability']

# %%
df['DayOfWeekClaimed'] = df['DayOfWeekClaimed'].replace('0', 'not claimed')
df['MonthClaimed'] = df['MonthClaimed'].replace('0', 'not claimed')

# %%
for col in cat_columns:
    ct = pd.crosstab(df[col], df['FraudFound_P'], normalize='index')
    print(f"\nFraude por categoría en '{col}':")
    display(ct)

    fraud_pct = ct[1]
    fraud_pct.plot(kind='bar', figsize=(10,4), title=f'% Fraude por {col}')
    plt.ylabel('Porcentaje de fraude')
    plt.show()
# Out:
# Fraude por categoría en 'Month':
# FraudFound_P         0         1
# Month
# Apr           0.952038  0.047962
# Aug           0.930636  0.069364
# Dec           0.961538  0.038462
# Feb           0.935162  0.064838
# Jan           0.928105  0.071895
# Jul           0.950119  0.049881
# Jun           0.944724  0.055276
# Mar           0.913832  0.086168
# May           0.932609  0.067391
# Nov           0.967337  0.032663
# Oct           0.948357  0.051643
# Sep           0.937650  0.062350
# Fraude por categoría en 'WeekOfMonth':
# FraudFound_P         0         1
# WeekOfMonth
# 1             0.947467  0.052533
# 2             0.942637  0.057363
# 3             0.940052  0.059948
# 4             0.933579  0.066421
# 5             0.947269  0.052731
# Fraude por categoría en 'DayOfWeek':
# FraudFound_P         0         1
# DayOfWeek
# Friday        0.943372  0.056628
# Monday        0.939535  0.060465
# Saturday      0.924559  0.075441
# Sunday        0.930508  0.069492
# Thursday      0.953757  0.046243
# Tuesday       0.947299  0.052701
# Wednesday     0.948498  0.051502
# Fraude por categoría en 'Make':
# FraudFound_P         0         1
# Make
# Accura        0.918750  0.081250
# BMW           1.000000  0.000000
# Chevrolet     0.956364  0.043636
# Dodge         0.969697  0.030303
# Ferrari       1.000000  0.000000
# Ford          0.924658  0.075342
# Honda         0.947195  0.052805
# Jaguar        1.000000  0.000000
# Mazda         0.937008  0.062992
# Mecedes       1.000000  0.000000
# Mercury       0.868421  0.131579
# Nisson        0.916667  0.083333
# Pontiac       0.936393  0.063607
# Porche        1.000000  0.000000
# Saab          0.909091  0.090909
# Saturn        0.952381  0.047619
# Toyota        0.944276  0.055724
# VW            0.968750  0.031250
# Fraude por categoría en 'AccidentArea':
# FraudFound_P         0         1
# AccidentArea
# Rural         0.912381  0.087619
# Urban         0.945028  0.054972
# Fraude por categoría en 'DayOfWeekClaimed':
# FraudFound_P             0         1
# DayOfWeekClaimed
# Friday            0.937576  0.062424
# Monday            0.948887  0.051113
# Saturday          0.897436  0.102564
# Sunday            0.950000  0.050000
# Thursday          0.939080  0.060920
# Tuesday           0.937273  0.062727
# Wednesday         0.944681  0.055319
# not claimed       1.000000  0.000000
# Fraude por categoría en 'MonthClaimed':
# FraudFound_P         0         1
# MonthClaimed
# Apr           0.941748  0.058252
# Aug           0.915493  0.084507
# Dec           0.961929  0.038071
# Feb           0.941748  0.058252
# Jan           0.926503  0.073497
# Jul           0.962217  0.037783
# Jun           0.948718  0.051282
# Mar           0.925170  0.074830
# May           0.926931  0.073069
# Nov           0.962871  0.037129
# Oct           0.953540  0.046460
# Sep           0.934783  0.065217
# not claimed   1.000000  0.000000
# Fraude por categoría en 'WeekOfMonthClaimed':
# FraudFound_P               0         1
# WeekOfMonthClaimed
# 1                   0.938704  0.061296
# 2                   0.957393  0.042607
# 3                   0.939138  0.060862
# 4                   0.932595  0.067405
# 5                   0.934177  0.065823
# Fraude por categoría en 'Sex':
# FraudFound_P         0         1
# Sex
# Female        0.955640  0.044360
# Male          0.938969  0.061031
# Fraude por categoría en 'MaritalStatus':
# FraudFound_P          0         1
# MaritalStatus
# Divorced       1.000000  0.000000
# Married        0.944673  0.055327
# Single         0.934017  0.065983
# Widow          0.900000  0.100000
# Fraude por categoría en 'Fault':
# FraudFound_P          0         1
# Fault
# Policy Holder  0.921768  0.078232
# Third Party    0.994842  0.005158
# Fraude por categoría en 'PolicyType':
# FraudFound_P                 0         1
# PolicyType
# Sedan - All Perils    0.899475  0.100525
# Sedan - Collision     0.931499  0.068501
# Sedan - Liability     0.991427  0.008573
# Sport - All Perils    1.000000  0.000000
# Sport - Collision     0.909091  0.090909
# Sport - Liability     1.000000  0.000000
# Utility - All Perils  0.892857  0.107143
# Utility - Collision   1.000000  0.000000
# Utility - Liability   1.000000  0.000000
# Fraude por categoría en 'VehicleCategory':
# FraudFound_P            0         1
# VehicleCategory
# Sedan            0.917791  0.082209
# Sport            0.986301  0.013699
# Utility          0.910448  0.089552
# Fraude por categoría en 'VehiclePrice':
# FraudFound_P            0         1
# VehiclePrice
# 20000 to 29000   0.948276  0.051724
# 30000 to 39000   0.947684  0.052316
# 40000 to 59000   0.930818  0.069182
# 60000 to 69000   0.965517  0.034483
# less than 20000  0.891429  0.108571
# more than 69000  0.932945  0.067055
# Fraude por categoría en 'Deductible':
# FraudFound_P         0         1
# Deductible
# 300           1.000000  0.000000
# 400           0.943809  0.056191
# 500           0.823529  0.176471
# 700           0.934579  0.065421
# Fraude por categoría en 'Days_Policy_Accident':
# FraudFound_P                 0         1
# Days_Policy_Accident
# 1 to 7                1.000000  0.000000
# 15 to 30              0.866667  0.133333
# 8 to 15               0.866667  0.133333
# more than 30          0.942343  0.057657
# none                  0.869565  0.130435
# Fraude por categoría en 'Days_Policy_Claim':
# FraudFound_P              0         1
# Days_Policy_Claim
# 15 to 30           0.823529  0.176471
# 8 to 15            0.875000  0.125000
# more than 30       0.942099  0.057901
# none               1.000000  0.000000
# Fraude por categoría en 'PastNumberOfClaims':
# FraudFound_P               0         1
# PastNumberOfClaims
# 1                   0.945159  0.054841
# 2 to 4              0.940767  0.059233
# more than 4         0.964018  0.035982
# none                0.929363  0.070637
# Fraude por categoría en 'AgeOfVehicle':
# FraudFound_P         0         1
# AgeOfVehicle
# 2 years       1.000000  0.000000
# 3 years       0.951220  0.048780
# 4 years       0.901408  0.098592
# 5 years       0.916854  0.083146
# 6 years       0.932633  0.067367
# 7 years       0.949468  0.050532
# more than 7   0.950394  0.049606
# new           0.914062  0.085938
# Fraude por categoría en 'AgeOfPolicyHolder':
# FraudFound_P              0         1
# AgeOfPolicyHolder
# 16 to 17           0.903509  0.096491
# 18 to 20           0.750000  0.250000
# 21 to 25           1.000000  0.000000
# 26 to 30           0.930000  0.070000
# 31 to 35           0.934620  0.065380
# 36 to 40           0.939655  0.060345
# 41 to 50           0.954343  0.045657
# 51 to 65           0.959551  0.040449
# over 65            0.954286  0.045714
# Fraude por categoría en 'PoliceReportFiled':
# FraudFound_P              0         1
# PoliceReportFiled
# No                 0.940584  0.059416
# Yes                0.977941  0.022059
# Fraude por categoría en 'WitnessPresent':
# FraudFound_P           0         1
# WitnessPresent
# No              0.941603  0.058397
# Yes             0.941176  0.058824
# Fraude por categoría en 'AgentType':
# FraudFound_P         0         1
# AgentType
# External      0.940709  0.059291
# Internal      0.989130  0.010870
# Fraude por categoría en 'NumberOfSuppliments':
# FraudFound_P                0         1
# NumberOfSuppliments
# 1 to 2               0.931421  0.068579
# 3 to 5               0.941896  0.058104
# more than 5          0.957997  0.042003
# none                 0.936253  0.063747
# Fraude por categoría en 'AddressChange_Claim':
# FraudFound_P                0         1
# AddressChange_Claim
# 1 year               0.907692  0.092308
# 2 to 3 years         0.835165  0.164835
# 4 to 8 years         0.944700  0.055300
# no change            0.944228  0.055772
# under 6 months       0.000000  1.000000
# Fraude por categoría en 'NumberOfCars':
# FraudFound_P         0         1
# NumberOfCars
# 1 vehicle     0.941848  0.058152
# 2 vehicles    0.934694  0.065306
# 3 to 4        0.944954  0.055046
# 5 to 8        1.000000  0.000000
# Fraude por categoría en 'Year':
# FraudFound_P         0         1
# Year
# 1994          0.935321  0.064679
# 1995          0.943761  0.056239
# 1996          0.948250  0.051750
# Fraude por categoría en 'BasePolicy':
# FraudFound_P         0         1
# BasePolicy
# All Perils    0.899518  0.100482
# Collision     0.930636  0.069364
# Liability     0.991484  0.008516

# %%
for col in df.columns:
    grouped = df.groupby(col).agg(
        count=(col, 'size'),
        fraud_rate=("FraudFound_P", 'mean')
    ).sort_values(by='fraud_rate', ascending=False)
    
    print(col)
    print(grouped)
# Out:
# Month
#        count  fraud_rate
# Month
# Mar      441    0.086168
# Jan      459    0.071895
# Aug      346    0.069364
# May      460    0.067391
# Feb      401    0.064838
# Sep      417    0.062350
# Jun      398    0.055276
# Oct      426    0.051643
# Jul      421    0.049881
# Apr      417    0.047962
# Dec      416    0.038462
# Nov      398    0.032663
# WeekOfMonth
#              count  fraud_rate
# WeekOfMonth
# 4             1084    0.066421
# 3             1151    0.059948
# 2             1168    0.057363
# 5              531    0.052731
# 1             1066    0.052533
# DayOfWeek
#            count  fraud_rate
# DayOfWeek
# Saturday     623    0.075441
# Sunday       590    0.069492
# Monday       860    0.060465
# Friday       777    0.056628
# Tuesday      759    0.052701
# Wednesday    699    0.051502
# Thursday     692    0.046243
# Make
#            count  fraud_rate
# Make
# Mercury       38    0.131579
# Saab          33    0.090909
# Nisson        12    0.083333
# Accura       160    0.081250
# Ford         146    0.075342
# Pontiac     1242    0.063607
# Mazda        762    0.062992
# Toyota       987    0.055724
# Honda        909    0.052805
# Saturn        21    0.047619
# Chevrolet    550    0.043636
# VW            96    0.031250
# Dodge         33    0.030303
# BMW            6    0.000000
# Porche         1    0.000000
# Jaguar         2    0.000000
# Ferrari        1    0.000000
# Mecedes        1    0.000000
# AccidentArea
#               count  fraud_rate
# AccidentArea
# Rural           525    0.087619
# Urban          4475    0.054972
# DayOfWeekClaimed
#                   count  fraud_rate
# DayOfWeekClaimed
# Saturday             39    0.102564
# Tuesday            1100    0.062727
# Friday              817    0.062424
# Thursday            870    0.060920
# Wednesday           940    0.055319
# Monday             1213    0.051113
# Sunday               20    0.050000
# not claimed           1    0.000000
# MonthClaimed
#               count  fraud_rate
# MonthClaimed
# Aug             355    0.084507
# Mar             441    0.074830
# Jan             449    0.073497
# May             479    0.073069
# Sep             414    0.065217
# Apr             412    0.058252
# Feb             412    0.058252
# Jun             390    0.051282
# Oct             452    0.046460
# Dec             394    0.038071
# Jul             397    0.037783
# Nov             404    0.037129
# not claimed       1    0.000000
# WeekOfMonthClaimed
#                     count  fraud_rate
# WeekOfMonthClaimed
# 4                    1083    0.067405
# 5                     395    0.065823
# 1                    1142    0.061296
# 3                    1183    0.060862
# 2                    1197    0.042607
# Sex
#         count  fraud_rate
# Sex
# Male     4211    0.061031
# Female    789    0.044360
# MaritalStatus
#                count  fraud_rate
# MaritalStatus
# Widow             10    0.100000
# Single          1561    0.065983
# Married         3398    0.055327
# Divorced          31    0.000000
# Fault
#                count  fraud_rate
# Fault
# Policy Holder   3643    0.078232
# Third Party     1357    0.005158
# PolicyType
#                       count  fraud_rate
# PolicyType
# Utility - All Perils    112    0.107143
# Sedan - All Perils     1333    0.100525
# Sport - Collision       110    0.090909
# Sedan - Collision      1781    0.068501
# Sedan - Liability      1633    0.008573
# Sport - All Perils        8    0.000000
# Sport - Liability         1    0.000000
# Utility - Collision      12    0.000000
# Utility - Liability      10    0.000000
# VehicleCategory
#                  count  fraud_rate
# VehicleCategory
# Utility            134    0.089552
# Sedan             3114    0.082209
# Sport             1752    0.013699
# VehiclePrice
#                  count  fraud_rate
# VehiclePrice
# less than 20000    350    0.108571
# 40000 to 59000     159    0.069182
# more than 69000    686    0.067055
# 30000 to 39000    1166    0.052316
# 20000 to 29000    2610    0.051724
# 60000 to 69000      29    0.034483
# FraudFound_P
#               count  fraud_rate
# FraudFound_P
# 1               292         1.0
# 0              4708         0.0
# Deductible
#             count  fraud_rate
# Deductible
# 500            85    0.176471
# 700           107    0.065421
# 400          4805    0.056191
# 300             3    0.000000
# Days_Policy_Accident
#                       count  fraud_rate
# Days_Policy_Accident
# 15 to 30                 15    0.133333
# 8 to 15                  15    0.133333
# none                     23    0.130435
# more than 30           4943    0.057657
# 1 to 7                    4    0.000000
# Days_Policy_Claim
#                    count  fraud_rate
# Days_Policy_Claim
# 15 to 30              17    0.176471
# 8 to 15                8    0.125000
# more than 30        4974    0.057901
# none                   1    0.000000
# PastNumberOfClaims
#                     count  fraud_rate
# PastNumberOfClaims
# none                 1444    0.070637
# 2 to 4               1722    0.059233
# 1                    1167    0.054841
# more than 4           667    0.035982
# AgeOfVehicle
#               count  fraud_rate
# AgeOfVehicle
# 4 years          71    0.098592
# new             128    0.085938
# 5 years         445    0.083146
# 6 years        1143    0.067367
# 7 years        1880    0.050532
# more than 7    1270    0.049606
# 3 years          41    0.048780
# 2 years          22    0.000000
# AgeOfPolicyHolder
#                    count  fraud_rate
# AgeOfPolicyHolder
# 18 to 20               4    0.250000
# 16 to 17             114    0.096491
# 26 to 30             200    0.070000
# 31 to 35            1866    0.065380
# 36 to 40            1276    0.060345
# over 65              175    0.045714
# 41 to 50             898    0.045657
# 51 to 65             445    0.040449
# 21 to 25              22    0.000000
# PoliceReportFiled
#                    count  fraud_rate
# PoliceReportFiled
# No                  4864    0.059416
# Yes                  136    0.022059
# WitnessPresent
#                 count  fraud_rate
# WitnessPresent
# Yes                34    0.058824
# No               4966    0.058397
# AgentType
#            count  fraud_rate
# AgentType
# External    4908    0.059291
# Internal      92    0.010870
# NumberOfSuppliments
#                      count  fraud_rate
# NumberOfSuppliments
# 1 to 2                 802    0.068579
# none                  2306    0.063747
# 3 to 5                 654    0.058104
# more than 5           1238    0.042003
# AddressChange_Claim
#                      count  fraud_rate
# AddressChange_Claim
# under 6 months           1    1.000000
# 2 to 3 years            91    0.164835
# 1 year                  65    0.092308
# no change             4626    0.055772
# 4 to 8 years           217    0.055300
# NumberOfCars
#               count  fraud_rate
# NumberOfCars
# 2 vehicles      245    0.065306
# 1 vehicle      4643    0.058152
# 3 to 4          109    0.055046
# 5 to 8            3    0.000000
# Year
#       count  fraud_rate
# Year
# 1994   1979    0.064679
# 1995   1707    0.056239
# 1996   1314    0.051750
# BasePolicy
#             count  fraud_rate
# BasePolicy
# All Perils   1453    0.100482
# Collision    1903    0.069364
# Liability    1644    0.008516

# %%
#small_makes = ["BMW", "Porche", "Jaguar", "Ferrari", "Mecedes"]

#df['Make'] = df['Make'].apply(lambda x: 'Other' if x in small_makes else x)

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split


def calc_woe_iv(df, feature):
    lst = []
    for val in df[feature].unique():
        total = df[df[feature] == val].shape[0]
        good = df[(df[feature] == val) & (df['FraudFound_P'] == 0)].shape[0]
        bad = df[(df[feature] == val) & (df['FraudFound_P'] == 1)].shape[0]
        lst.append({'categoria': val, 'Total': total, 'Good': good, 'Bad': bad})

    woe_df = pd.DataFrame(lst)
    woe_df['Distr_Good'] = (woe_df['Good'] / woe_df['Good'].sum()).replace(0, 0.0001)
    woe_df['Distr_Bad'] = (woe_df['Bad'] / woe_df['Bad'].sum()).replace(0, 0.0001)
    woe_df['WOE'] = np.log(woe_df['Distr_Good'] / woe_df['Distr_Bad'])
    woe_df['IV'] = (woe_df['Distr_Good'] - woe_df['Distr_Bad']) * woe_df['WOE']
    iv = woe_df['IV'].sum()
    return woe_df[['categoria', 'WOE']], iv

iv_values = {}

for col in cat_columns:
    _, iv = calc_woe_iv(df, col)
    iv_values[col] = iv

# %%
dict(sorted(iv_values.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'PolicyType': 0.7525236005691855,
#  'Fault': 0.7345403800845165,
#  'BasePolicy': 0.734485763539551,
#  'VehicleCategory': 0.5323586924143383,
#  'MonthClaimed': 0.08156263399863936,
#  'Month': 0.07293989185777808,
#  'AgeOfVehicle': 0.06520978949175817,
#  'AgeOfPolicyHolder': 0.06260804563390271,
#  'VehiclePrice': 0.05995057900536832,
#  'AddressChange_Claim': 0.05879119758178212,
#  'Deductible': 0.048159185602562986,
#  'PastNumberOfClaims': 0.041770007430939296,
#  'MaritalStatus': 0.03581652388383367,
#  'NumberOfSuppliments': 0.03488687662006107,
#  'WeekOfMonthClaimed': 0.03069626474074343,
#  'Make': 0.02920684468012676,
#  'AccidentArea': 0.027970474852934683,
#  'AgentType': 0.027779488517234666,
#  'DayOfWeek': 0.026992073292361717}

# %%
selected_columns = [col for col, iv in iv_values.items() if iv >= 0.02]
df_selected_columns = df[selected_columns + ['FraudFound_P']]
df_selected_columns
# Out:
#      Month DayOfWeek       Make AccidentArea MonthClaimed  WeekOfMonthClaimed  \
# 0      Aug    Friday      Honda        Urban          Aug                   5
# 1      Dec   Tuesday  Chevrolet        Urban          Dec                   3
# 2      Feb    Sunday  Chevrolet        Urban          Feb                   3
# 3      Jun   Tuesday    Pontiac        Urban          Jul                   4
# 4      Jan    Sunday     Toyota        Rural          Jan                   3
# ...    ...       ...        ...          ...          ...                 ...
# 4995   Sep    Friday     Toyota        Urban          Sep                   2
# 4996   Mar    Monday     Toyota        Urban          Mar                   4
# 4997   Feb  Saturday      Honda        Urban          Feb                   2
# 4998   Oct    Monday      Mazda        Urban          Nov                   2
# 4999   May    Sunday  Chevrolet        Urban          May                   3
#
#      MaritalStatus          Fault          PolicyType VehicleCategory  \
# 0          Married  Policy Holder  Sedan - All Perils           Sedan
# 1           Single    Third Party   Sedan - Collision           Sedan
# 2           Single  Policy Holder   Sedan - Liability           Sport
# 3          Married  Policy Holder   Sedan - Collision           Sedan
# 4           Single  Policy Holder  Sedan - All Perils           Sedan
# ...            ...            ...                 ...             ...
# 4995        Single  Policy Holder   Sedan - Liability           Sport
# 4996       Married  Policy Holder  Sedan - All Perils           Sedan
# 4997        Single  Policy Holder   Sedan - Liability           Sport
# 4998        Single    Third Party   Sedan - Collision           Sedan
# 4999        Single  Policy Holder   Sedan - Collision           Sedan
#
#          VehiclePrice  Deductible PastNumberOfClaims AgeOfVehicle  \
# 0      30000 to 39000         400                  1      7 years
# 1      20000 to 29000         400             2 to 4      5 years
# 2      20000 to 29000         400             2 to 4      6 years
# 3      20000 to 29000         400                  1      7 years
# 4     less than 20000         400               none      6 years
# ...               ...         ...                ...          ...
# 4995  more than 69000         400             2 to 4      7 years
# 4996   20000 to 29000         400               none  more than 7
# 4997  more than 69000         400        more than 4          new
# 4998   20000 to 29000         400                  1      5 years
# 4999   20000 to 29000         400               none      6 years
#
#      AgeOfPolicyHolder AgentType NumberOfSuppliments AddressChange_Claim  \
# 0             36 to 40  External              1 to 2        4 to 8 years
# 1             31 to 35  External                none           no change
# 2             31 to 35  External         more than 5           no change
# 3             41 to 50  External                none           no change
# 4             36 to 40  External                none           no change
# ...                ...       ...                 ...                 ...
# 4995          36 to 40  External         more than 5           no change
# 4996           over 65  External         more than 5           no change
# 4997          16 to 17  External                none           no change
# 4998          31 to 35  External                none           no change
# 4999          31 to 35  External                none           no change
#
#       BasePolicy  FraudFound_P
# 0     All Perils             0
# 1      Collision             0
# 2      Liability             0
# 3      Collision             0
# 4     All Perils             1
# ...          ...           ...
# 4995   Liability             0
# 4996  All Perils             0
# 4997   Liability             0
# 4998   Collision             0
# 4999   Collision             1
#
# [5000 rows x 20 columns]

# %%
def sugerir_binning(df, woe_dict, target='FraudFound_P', min_freq=0.01, max_woe_diff=0.1):
    sugerencias = {}

    for col, woe_map in woe_dict.items():
        col_sugerencias = []
        series = df[col]
        total = len(series)

        # Calcula frecuencia por clase
        freq_df = df.groupby([col, target]).size().unstack(fill_value=0)
        freq_df = freq_df / freq_df.sum(axis=0)  # frecuencia relativa por clase
        woe_map['freq_target_0'] = woe_map['categoria'].map(freq_df[0])
        woe_map['freq_target_1'] = woe_map['categoria'].map(freq_df[1])

        # Ordena por WOE
        woe_map_sorted = woe_map.sort_values('WOE').reset_index(drop=True)

        similares_y_bajas = []
        for i in range(len(woe_map_sorted)-1):
            cat1 = woe_map_sorted.iloc[i]['categoria']
            cat2 = woe_map_sorted.iloc[i+1]['categoria']
            woe1 = woe_map_sorted.iloc[i]['WOE']
            woe2 = woe_map_sorted.iloc[i+1]['WOE']

            freq1_0 = woe_map_sorted.iloc[i]['freq_target_0']
            freq1_1 = woe_map_sorted.iloc[i]['freq_target_1']
            freq2_0 = woe_map_sorted.iloc[i+1]['freq_target_0']
            freq2_1 = woe_map_sorted.iloc[i+1]['freq_target_1']

            # Condición: WOE similar y baja frecuencia en ambas clases
            if (abs(woe2 - woe1) < max_woe_diff and
                freq1_0 < min_freq and freq1_1 < min_freq and
                freq2_0 < min_freq and freq2_1 < min_freq):
                similares_y_bajas.append((cat1, cat2))

        if similares_y_bajas:
            col_sugerencias.append(similares_y_bajas)

        if col_sugerencias:
            sugerencias[col] = col_sugerencias

    return sugerencias

# %%
woe_dict = {}
iv_values = {}

for col in selected_columns:
    woe_table, iv = calc_woe_iv(df_selected_columns, col)
    woe_dict[col] = woe_table
    iv_values[col] = iv

# %%
sugerir_binning(df_selected_columns, woe_dict)
# Out:
# {'Make': [[('Dodge', 'Porche'),
#    ('Porche', 'Ferrari'),
#    ('Ferrari', 'Mecedes')]]}

# %%
woe_dict["Make"].sort_values('WOE').reset_index(drop=True)
# Out:
#     categoria       WOE  freq_target_0  freq_target_1
# 0     Mercury -0.893195       0.007009       0.017123
# 1        Saab -0.477680       0.006372       0.010274
# 2      Nisson -0.382369       0.002336       0.003425
# 3      Accura -0.354781       0.031223       0.044521
# 4        Ford -0.272885       0.028675       0.037671
# 5     Pontiac -0.090954       0.247026       0.270548
# 6       Mazda -0.080583       0.151657       0.164384
# 7      Toyota  0.049735       0.197961       0.188356
# 8       Honda  0.106629       0.182880       0.164384
# 9      Saturn  0.215468       0.004248       0.003425
# 10  Chevrolet  0.306983       0.111725       0.082192
# 11         VW  0.653723       0.019754       0.010274
# 12      Dodge  0.685471       0.006797       0.003425
# 13     Porche  0.753322       0.000212       0.000000
# 14    Ferrari  0.753322       0.000212       0.000000
# 15    Mecedes  0.753322       0.000212       0.000000
# 16     Jaguar  1.446469       0.000425       0.000000
# 17        BMW  2.545081       0.001274       0.000000

# %% [markdown]
# ## Processing

# %%
replace_map = {
    'Porche': 'Luxyry',
    'Ferrari': 'Luxyry',
    'Mecedes': 'Luxyry'
}

# Aplica el reemplazo
df_final = df_selected_columns.copy()
df_final['Make'] = df_final['Make'].replace(replace_map)

# %%
woe_dict = {}
iv_values = {}

for col in selected_columns:
    woe_table, iv = calc_woe_iv(df_final, col)
    woe_dict[col] = woe_table
    iv_values[col] = iv
    df_final[col + '_woe'] = df_final[col].map(dict(zip(woe_table['categoria'], woe_table['WOE'])))

# %%
df_final
# Out:
#      Month DayOfWeek       Make AccidentArea MonthClaimed  WeekOfMonthClaimed  \
# 0      Aug    Friday      Honda        Urban          Aug                   5
# 1      Dec   Tuesday  Chevrolet        Urban          Dec                   3
# 2      Feb    Sunday  Chevrolet        Urban          Feb                   3
# 3      Jun   Tuesday    Pontiac        Urban          Jul                   4
# 4      Jan    Sunday     Toyota        Rural          Jan                   3
# ...    ...       ...        ...          ...          ...                 ...
# 4995   Sep    Friday     Toyota        Urban          Sep                   2
# 4996   Mar    Monday     Toyota        Urban          Mar                   4
# 4997   Feb  Saturday      Honda        Urban          Feb                   2
# 4998   Oct    Monday      Mazda        Urban          Nov                   2
# 4999   May    Sunday  Chevrolet        Urban          May                   3
#
#      MaritalStatus          Fault          PolicyType VehicleCategory  \
# 0          Married  Policy Holder  Sedan - All Perils           Sedan
# 1           Single    Third Party   Sedan - Collision           Sedan
# 2           Single  Policy Holder   Sedan - Liability           Sport
# 3          Married  Policy Holder   Sedan - Collision           Sedan
# 4           Single  Policy Holder  Sedan - All Perils           Sedan
# ...            ...            ...                 ...             ...
# 4995        Single  Policy Holder   Sedan - Liability           Sport
# 4996       Married  Policy Holder  Sedan - All Perils           Sedan
# 4997        Single  Policy Holder   Sedan - Liability           Sport
# 4998        Single    Third Party   Sedan - Collision           Sedan
# 4999        Single  Policy Holder   Sedan - Collision           Sedan
#
#          VehiclePrice  Deductible PastNumberOfClaims AgeOfVehicle  \
# 0      30000 to 39000         400                  1      7 years
# 1      20000 to 29000         400             2 to 4      5 years
# 2      20000 to 29000         400             2 to 4      6 years
# 3      20000 to 29000         400                  1      7 years
# 4     less than 20000         400               none      6 years
# ...               ...         ...                ...          ...
# 4995  more than 69000         400             2 to 4      7 years
# 4996   20000 to 29000         400               none  more than 7
# 4997  more than 69000         400        more than 4          new
# 4998   20000 to 29000         400                  1      5 years
# 4999   20000 to 29000         400               none      6 years
#
#      AgeOfPolicyHolder AgentType NumberOfSuppliments AddressChange_Claim  \
# 0             36 to 40  External              1 to 2        4 to 8 years
# 1             31 to 35  External                none           no change
# 2             31 to 35  External         more than 5           no change
# 3             41 to 50  External                none           no change
# 4             36 to 40  External                none           no change
# ...                ...       ...                 ...                 ...
# 4995          36 to 40  External         more than 5           no change
# 4996           over 65  External         more than 5           no change
# 4997          16 to 17  External                none           no change
# 4998          31 to 35  External                none           no change
# 4999          31 to 35  External                none           no change
#
#       BasePolicy  FraudFound_P  Month_woe  DayOfWeek_woe  Make_woe  \
# 0     All Perils             0  -0.183767       0.032691  0.106629
# 1      Collision             0   0.438611       0.108717  0.306983
# 2      Liability             0  -0.111435      -0.185738  0.306983
# 3      Collision             0   0.058282       0.108717 -0.090954
# 4     All Perils             1  -0.222333      -0.185738  0.049735
# ...          ...           ...        ...            ...       ...
# 4995   Liability             0  -0.069654       0.032691  0.049735
# 4996  All Perils             0  -0.418914      -0.036946  0.049735
# 4997   Liability             0  -0.111435      -0.274305  0.106629
# 4998   Collision             0   0.130108      -0.036946 -0.080583
# 4999   Collision             1  -0.152795      -0.185738  0.306983
#
#       AccidentArea_woe  MonthClaimed_woe  WeekOfMonthClaimed_woe  \
# 0             0.064125         -0.397637               -0.127565
# 1             0.064125          0.449221               -0.043915
# 2             0.064125          0.002687               -0.043915
# 3             0.064125          0.457106               -0.153018
# 4            -0.437205         -0.246087               -0.043915
# ...                ...               ...                     ...
# 4995          0.064125         -0.117677                0.331943
# 4996          0.064125         -0.265505               -0.153018
# 4997          0.064125          0.002687                0.331943
# 4998          0.064125          0.475264                0.331943
# 4999          0.064125         -0.239788               -0.043915
#
#       MaritalStatus_woe  Fault_woe  PolicyType_woe  VehicleCategory_woe  \
# 0              0.057320  -0.313653       -0.588861            -0.367565
# 1             -0.130173   2.481685       -0.170315            -0.367565
# 2             -0.130173  -0.313653        1.970242             1.496401
# 3              0.057320  -0.313653       -0.170315            -0.367565
# 4             -0.130173  -0.313653       -0.588861            -0.367565
# ...                 ...        ...             ...                  ...
# 4995          -0.130173  -0.313653        1.970242             1.496401
# 4996           0.057320  -0.313653       -0.588861            -0.367565
# 4997          -0.130173  -0.313653        1.970242             1.496401
# 4998          -0.130173   2.481685       -0.170315            -0.367565
# 4999          -0.130173  -0.313653       -0.170315            -0.367565
#
#       VehiclePrice_woe  Deductible_woe  PastNumberOfClaims_woe  \
# 0             0.116462        0.040894                0.066641
# 1             0.128456        0.040894               -0.015056
# 2             0.128456        0.040894               -0.015056
# 3             0.128456        0.040894                0.066641
# 4            -0.674848        0.040894               -0.203321
# ...                ...             ...                     ...
# 4995         -0.147438        0.040894               -0.015056
# 4996          0.128456        0.040894               -0.203321
# 4997         -0.147438        0.040894                0.507826
# 4998          0.128456        0.040894                0.066641
# 4999          0.128456        0.040894               -0.203321
#
#       AgeOfVehicle_woe  AgeOfPolicyHolder_woe  AgentType_woe  \
# 0             0.153032              -0.034827      -0.016088
# 1            -0.379915              -0.120349      -0.016088
# 2            -0.152401              -0.120349      -0.016088
# 3             0.153032               0.259601      -0.016088
# 4            -0.152401              -0.034827      -0.016088
# ...                ...                    ...            ...
# 4995          0.153032              -0.034827      -0.016088
# 4996          0.172494               0.258288      -0.016088
# 4997         -0.415986              -0.543431      -0.016088
# 4998         -0.379915              -0.120349      -0.016088
# 4999         -0.152401              -0.120349      -0.016088
#
#       NumberOfSuppliments_woe  AddressChange_Claim_woe  BasePolicy_woe
# 0                   -0.171533                 0.057839       -0.588382
# 1                   -0.093297                 0.048836       -0.183767
# 2                    0.346833                 0.048836        1.977013
# 3                   -0.093297                 0.048836       -0.183767
# 4                   -0.093297                 0.048836       -0.588382
# ...                       ...                      ...             ...
# 4995                 0.346833                 0.048836        1.977013
# 4996                 0.346833                 0.048836       -0.588382
# 4997                -0.093297                 0.048836        1.977013
# 4998                -0.093297                 0.048836       -0.183767
# 4999                -0.093297                 0.048836       -0.183767
#
# [5000 rows x 39 columns]

# %%
woe_cols = [col + '_woe' for col in selected_columns]
X = df_final[woe_cols].fillna(0)
y = df_final['FraudFound_P']

# %%
X
# Out:
#       Month_woe  DayOfWeek_woe  Make_woe  AccidentArea_woe  MonthClaimed_woe  \
# 0     -0.183767       0.032691  0.106629          0.064125         -0.397637
# 1      0.438611       0.108717  0.306983          0.064125          0.449221
# 2     -0.111435      -0.185738  0.306983          0.064125          0.002687
# 3      0.058282       0.108717 -0.090954          0.064125          0.457106
# 4     -0.222333      -0.185738  0.049735         -0.437205         -0.246087
# ...         ...            ...       ...               ...               ...
# 4995  -0.069654       0.032691  0.049735          0.064125         -0.117677
# 4996  -0.418914      -0.036946  0.049735          0.064125         -0.265505
# 4997  -0.111435      -0.274305  0.106629          0.064125          0.002687
# 4998   0.130108      -0.036946 -0.080583          0.064125          0.475264
# 4999  -0.152795      -0.185738  0.306983          0.064125         -0.239788
#
#       WeekOfMonthClaimed_woe  MaritalStatus_woe  Fault_woe  PolicyType_woe  \
# 0                  -0.127565           0.057320  -0.313653       -0.588861
# 1                  -0.043915          -0.130173   2.481685       -0.170315
# 2                  -0.043915          -0.130173  -0.313653        1.970242
# 3                  -0.153018           0.057320  -0.313653       -0.170315
# 4                  -0.043915          -0.130173  -0.313653       -0.588861
# ...                      ...                ...        ...             ...
# 4995                0.331943          -0.130173  -0.313653        1.970242
# 4996               -0.153018           0.057320  -0.313653       -0.588861
# 4997                0.331943          -0.130173  -0.313653        1.970242
# 4998                0.331943          -0.130173   2.481685       -0.170315
# 4999               -0.043915          -0.130173  -0.313653       -0.170315
#
#       VehicleCategory_woe  VehiclePrice_woe  Deductible_woe  \
# 0               -0.367565          0.116462        0.040894
# 1               -0.367565          0.128456        0.040894
# 2                1.496401          0.128456        0.040894
# 3               -0.367565          0.128456        0.040894
# 4               -0.367565         -0.674848        0.040894
# ...                   ...               ...             ...
# 4995             1.496401         -0.147438        0.040894
# 4996            -0.367565          0.128456        0.040894
# 4997             1.496401         -0.147438        0.040894
# 4998            -0.367565          0.128456        0.040894
# 4999            -0.367565          0.128456        0.040894
#
#       PastNumberOfClaims_woe  AgeOfVehicle_woe  AgeOfPolicyHolder_woe  \
# 0                   0.066641          0.153032              -0.034827
# 1                  -0.015056         -0.379915              -0.120349
# 2                  -0.015056         -0.152401              -0.120349
# 3                   0.066641          0.153032               0.259601
# 4                  -0.203321         -0.152401              -0.034827
# ...                      ...               ...                    ...
# 4995               -0.015056          0.153032              -0.034827
# 4996               -0.203321          0.172494               0.258288
# 4997                0.507826         -0.415986              -0.543431
# 4998                0.066641         -0.379915              -0.120349
# 4999               -0.203321         -0.152401              -0.120349
#
#       AgentType_woe  NumberOfSuppliments_woe  AddressChange_Claim_woe  \
# 0         -0.016088                -0.171533                 0.057839
# 1         -0.016088                -0.093297                 0.048836
# 2         -0.016088                 0.346833                 0.048836
# 3         -0.016088                -0.093297                 0.048836
# 4         -0.016088                -0.093297                 0.048836
# ...             ...                      ...                      ...
# 4995      -0.016088                 0.346833                 0.048836
# 4996      -0.016088                 0.346833                 0.048836
# 4997      -0.016088                -0.093297                 0.048836
# 4998      -0.016088                -0.093297                 0.048836
# 4999      -0.016088                -0.093297                 0.048836
#
#       BasePolicy_woe
# 0          -0.588382
# 1          -0.183767
# 2           1.977013
# 3          -0.183767
# 4          -0.588382
# ...              ...
# 4995        1.977013
# 4996       -0.588382
# 4997        1.977013
# 4998       -0.183767
# 4999       -0.183767
#
# [5000 rows x 19 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 4995    0
# 4996    0
# 4997    0
# 4998    0
# 4999    1
# Name: FraudFound_P, Length: 5000, dtype: int64
